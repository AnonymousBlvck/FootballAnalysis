# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###### Read the csv file using pandas

# %%
data_file_pd=pd.read_csv("PL17_18.csv")

# %% [markdown]
# ###### An over view of the data the first 5 columns

# %%
data_file_pd.head()
# Out:
#   Div        Date        HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  11/08/2017         Arsenal     Leicester     4     3   H     2     2
# 1  E0  12/08/2017        Brighton      Man City     0     2   A     0     0
# 2  E0  12/08/2017         Chelsea       Burnley     2     3   A     0     3
# 3  E0  12/08/2017  Crystal Palace  Huddersfield     0     3   A     0     2
# 4  E0  12/08/2017         Everton         Stoke     1     0   H     1     0
#
#   HTR  ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA   PSCH  \
# 0   D  ...     2.32    21  -1.00     1.91     1.85     2.10     2.02   1.49
# 1   D  ...     2.27    20   1.50     1.95     1.91     2.01     1.96  11.75
# 2   A  ...     2.23    20  -1.75     2.03     1.97     1.95     1.90   1.33
# 3   A  ...     1.72    18  -0.75     2.10     2.05     1.86     1.83   1.79
# 4   H  ...     1.76    19  -0.75     1.94     1.90     2.01     1.98   1.82
#
#    PSCD   PSCA
# 0  4.73   7.25
# 1  6.15   1.29
# ...

# %% [markdown]
# ###### iloc : integer location

# %%
data_file_pd.iloc[0] #iloc : integer location
# Out:
# Div                 E0
# Date        11/08/2017
# HomeTeam       Arsenal
# AwayTeam     Leicester
# FTHG                 4
#                ...
# BbMxAHA            2.1
# BbAvAHA           2.02
# PSCH              1.49
# PSCD              4.73
# PSCA              7.25
# Name: 0, Length: 65, dtype: object

# %% [markdown]
# ###### All the games played by liverpool 18/19 season

# %%
c=data_file_pd.loc[(data_file_pd["HomeTeam"]=="Liverpool") | (data_file_pd["AwayTeam"]=="Liverpool")]
data_file_pd.loc[(data_file_pd["HomeTeam"]=="Liverpool") | (data_file_pd["AwayTeam"]=="Liverpool")]
# Out:
#     Div        Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 6    E0  12/08/2017         Watford       Liverpool     3     3   D     2
# 13   E0  19/08/2017       Liverpool  Crystal Palace     1     0   H     0
# 27   E0  27/08/2017       Liverpool         Arsenal     4     0   H     2
# 34   E0  09/09/2017        Man City       Liverpool     5     0   H     2
# 43   E0  16/09/2017       Liverpool         Burnley     1     1   D     1
# 52   E0  23/09/2017       Leicester       Liverpool     2     3   A     1
# 69   E0  01/10/2017       Newcastle       Liverpool     1     1   D     1
# 72   E0  14/10/2017       Liverpool      Man United     0     0   D     0
# 89   E0  22/10/2017       Tottenham       Liverpool     4     1   H     3
# 93   E0  28/10/2017       Liverpool    Huddersfield     3     0   H     0
# 105  E0  04/11/2017        West Ham       Liverpool     1     4   A     0
# 115  E0  18/11/2017       Liverpool     Southampton     3     0   H     2
# ...

# %% [markdown]
# ###### Liverpool wins

# %%
LivWins=data_file_pd.loc[((data_file_pd["HomeTeam"]=="Liverpool") & (data_file_pd["FTR"]=="H")) | ((data_file_pd["AwayTeam"]=="Liverpool") & (data_file_pd["FTR"]=="A") )]
LivWins
# Out:
#     Div        Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 13   E0  19/08/2017       Liverpool  Crystal Palace     1     0   H     0
# 27   E0  27/08/2017       Liverpool         Arsenal     4     0   H     2
# 52   E0  23/09/2017       Leicester       Liverpool     2     3   A     1
# 93   E0  28/10/2017       Liverpool    Huddersfield     3     0   H     0
# 105  E0  04/11/2017        West Ham       Liverpool     1     4   A     0
# 115  E0  18/11/2017       Liverpool     Southampton     3     0   H     2
# 139  E0  29/11/2017           Stoke       Liverpool     0     3   A     0
# 141  E0  02/12/2017        Brighton       Liverpool     1     5   A     0
# 177  E0  17/12/2017     Bournemouth       Liverpool     0     4   A     0
# 193  E0  26/12/2017       Liverpool         Swansea     5     0   H     1
# 203  E0  30/12/2017       Liverpool       Leicester     2     1   H     0
# 210  E0  01/01/2018         Burnley       Liverpool     1     2   A     0
# ...

# %% [markdown]
# ###### Liverpool odds : BET 365

# %%
LivOddsBet365Home=LivOddsBet365.loc[LivOddsBet365["FTR"]=="H"]
LivOddsBet365Home
# Out:
#       HomeTeam        AwayTeam FTR  B365H  B365D  B365A
# 13   Liverpool  Crystal Palace   H   1.36   5.25   9.50
# 27   Liverpool         Arsenal   H   2.15   3.70   3.50
# 93   Liverpool    Huddersfield   H   1.25   6.75  13.00
# 115  Liverpool     Southampton   H   1.39   5.00   9.00
# 193  Liverpool         Swansea   H   1.16   9.00  19.00
# 203  Liverpool       Leicester   H   1.30   6.00  11.00
# 228  Liverpool        Man City   H   3.10   3.75   2.29
# 274  Liverpool        West Ham   H   1.22   7.50  13.00
# 282  Liverpool       Newcastle   H   1.22   7.00  15.00
# 302  Liverpool         Watford   H   1.19   8.00  15.00
# 327  Liverpool     Bournemouth   H   1.25   7.00  12.00
# 373  Liverpool        Brighton   H   1.19   8.00  15.00

# %%
LivOddsBet365Away=LivOddsBet365.loc[LivOddsBet365["FTR"]=="A"]
LivOddsBet365Away
# Out:
#            HomeTeam   AwayTeam FTR  B365H  B365D  B365A
# 52        Leicester  Liverpool   A   4.10   3.90   1.91
# 105        West Ham  Liverpool   A   5.25   4.33   1.66
# 139           Stoke  Liverpool   A   6.50   4.50   1.55
# 141        Brighton  Liverpool   A   7.50   4.50   1.50
# 177     Bournemouth  Liverpool   A   6.50   4.50   1.53
# 210         Burnley  Liverpool   A   7.50   4.50   1.50
# 240    Huddersfield  Liverpool   A  12.00   5.75   1.30
# 268     Southampton  Liverpool   A   4.20   3.79   1.80
# 305  Crystal Palace  Liverpool   A   7.00   4.33   1.44

# %%
LivOddsBet365Home=LivOddsBet365.loc[LivOddsBet365["FTR"]=="H"]
totalHome=LivOddsBet365Home["B365H"].sum()
LivOddsBet365Away=LivOddsBet365.loc[LivOddsBet365["FTR"]=="A"]
totalAway=LivOddsBet365Away["B365A"].sum()
TotalOdds=totalHome+totalAway
print("Total season odds : ",TotalOdds)
# Out:
# Total season odds :  31.97

# %%
BetValue=1000
Savings=BetValue*38
Profit=BetValue*TotalOdds-Savings
print("bet value : ", BetValue)
print("Full season has 38 matches : ", Savings)
print("The profit of last on liverpool is : ", Profit)
# Out:
# bet value :  1000
# Full season has 38 matches :  38000
# The profit of last on liverpool is :  -6030.0
